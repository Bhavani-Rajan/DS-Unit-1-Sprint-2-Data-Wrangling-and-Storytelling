# %% [markdown]
# <a href="https://colab.research.google.com/github/Bhavani-Rajan/DS-Unit-1-Sprint-2-Data-Wrangling-and-Storytelling/blob/master/module1-join-and-reshape-data/LS_DS_121_Join_and_Reshape_Data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# _Lambda School Data Science_
#
# # Join and Reshape datasets
#
# Objectives
# - concatenate data with pandas
# - merge data with pandas
# -  understand tidy data formatting
# -  melt and pivot data with pandas
#
# Links
# - [Pandas Cheat Sheet](https://github.com/pandas-dev/pandas/blob/master/doc/cheatsheet/Pandas_Cheat_Sheet.pdf)
# - [Tidy Data](https://en.wikipedia.org/wiki/Tidy_data)
#   - Combine Data Sets: Standard Joins
#   - Tidy Data
#   - Reshaping Data
# - Python Data Science Handbook
#   - [Chapter 3.6](https://jakevdp.github.io/PythonDataScienceHandbook/03.06-concat-and-append.html), Combining Datasets: Concat and Append
#   - [Chapter 3.7](https://jakevdp.github.io/PythonDataScienceHandbook/03.07-merge-and-join.html), Combining Datasets: Merge and Join
#   - [Chapter 3.8](https://jakevdp.github.io/PythonDataScienceHandbook/03.08-aggregation-and-grouping.html), Aggregation and Grouping
#   - [Chapter 3.9](https://jakevdp.github.io/PythonDataScienceHandbook/03.09-pivot-tables.html), Pivot Tables
#
# Reference
# - Pandas Documentation: [Reshaping and Pivot Tables](https://pandas.pydata.org/pandas-docs/stable/reshaping.html)
# - Modern Pandas, Part 5: [Tidy Data](https://tomaugspurger.github.io/modern-5-tidy.html)
# - [Hadley Wickham's famous paper](http://vita.had.co.nz/papers/tidy-data.html) on Tidy Data

# %% [markdown]
# ## Download data
#
# We’ll work with a dataset of [3 Million Instacart Orders, Open Sourced](https://tech.instacart.com/3-million-instacart-orders-open-sourced-d40d29ead6f2)!

# %%
# !wget https://s3.amazonaws.com/instacart-datasets/instacart_online_grocery_shopping_2017_05_01.tar.gz
# Out:
# --2019-09-10 20:02:56--  https://s3.amazonaws.com/instacart-datasets/instacart_online_grocery_shopping_2017_05_01.tar.gz
# Resolving s3.amazonaws.com (s3.amazonaws.com)... 52.216.138.181
# Connecting to s3.amazonaws.com (s3.amazonaws.com)|52.216.138.181|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 205548478 (196M) [application/x-gzip]
# Saving to: ‘instacart_online_grocery_shopping_2017_05_01.tar.gz’
#
# instacart_online_gr 100%[===================>] 196.03M  80.3MB/s    in 2.4s
#
# 2019-09-10 20:02:59 (80.3 MB/s) - ‘instacart_online_grocery_shopping_2017_05_01.tar.gz’ saved [205548478/205548478]

# %%
# !tar --gunzip --extract --verbose --file=instacart_online_grocery_shopping_2017_05_01.tar.gz
# Out:
# instacart_2017_05_01/
# instacart_2017_05_01/._aisles.csv
# instacart_2017_05_01/aisles.csv
# instacart_2017_05_01/._departments.csv
# instacart_2017_05_01/departments.csv
# instacart_2017_05_01/._order_products__prior.csv
# instacart_2017_05_01/order_products__prior.csv
# instacart_2017_05_01/._order_products__train.csv
# instacart_2017_05_01/order_products__train.csv
# instacart_2017_05_01/._orders.csv
# instacart_2017_05_01/orders.csv
# instacart_2017_05_01/._products.csv
# instacart_2017_05_01/products.csv

# %%
# magic commands or bash command .. cd is for change directory
# %cd instacart_2017_05_01
# Out:
# /content/instacart_2017_05_01

# %%
# !ls -lh *.csv
# Out:
# -rw-r--r-- 1 502 staff 2.6K May  2  2017 aisles.csv
# -rw-r--r-- 1 502 staff  270 May  2  2017 departments.csv
# -rw-r--r-- 1 502 staff 551M May  2  2017 order_products__prior.csv
# -rw-r--r-- 1 502 staff  24M May  2  2017 order_products__train.csv
# -rw-r--r-- 1 502 staff 104M May  2  2017 orders.csv
# -rw-r--r-- 1 502 staff 2.1M May  2  2017 products.csv

# %% [markdown]
# # Join Datasets

# %% [markdown]
# ## Goal: Reproduce this example
#
# The first two orders for user id 1:

# %%
from IPython.display import display, Image
url = 'https://cdn-images-1.medium.com/max/1600/1*vYGFQCafJtGBBX5mbl0xyw.png'
example = Image(url=url, width=600)

display(example)
# Out:
# <img src="https://cdn-images-1.medium.com/max/1600/1*vYGFQCafJtGBBX5mbl0xyw.png" width="600"/>

# %% [markdown]
# ## Load data
#
# Here's a list of all six CSV filenames

# %%
# !ls -lh *.csv
# Out:
# -rw-r--r-- 1 502 staff 2.6K May  2  2017 aisles.csv
# -rw-r--r-- 1 502 staff  270 May  2  2017 departments.csv
# -rw-r--r-- 1 502 staff 551M May  2  2017 order_products__prior.csv
# -rw-r--r-- 1 502 staff  24M May  2  2017 order_products__train.csv
# -rw-r--r-- 1 502 staff 104M May  2  2017 orders.csv
# -rw-r--r-- 1 502 staff 2.1M May  2  2017 products.csv

# %% [markdown]
# For each CSV
# - Load it with pandas
# - Look at the dataframe's shape
# - Look at its head (first rows)
# - `display(example)`
# - Which columns does it have in common with the example we want to reproduce?

# %% [markdown]
# ### aisles

# %%
import pandas as pd

aisles = pd.read_csv('aisles.csv')

print(aisles.shape)
aisles.head(10)
# Out:
# (134, 2)
#    aisle_id                       aisle
# 0         1       prepared soups salads
# 1         2           specialty cheeses
# 2         3         energy granola bars
# 3         4               instant foods
# 4         5  marinades meat preparation
# 5         6                       other
# 6         7               packaged meat
# 7         8             bakery desserts
# 8         9                 pasta sauce
# 9        10            kitchen supplies

# %% [markdown]
# aisles.csv doesn't have cols that we need

# %% [markdown]
# ### departments

# %%
departments = pd.read_csv('departments.csv')

print(departments.shape)
departments.head(10)
# Out:
# (21, 2)
#    department_id       department
# 0              1           frozen
# 1              2            other
# 2              3           bakery
# 3              4          produce
# 4              5          alcohol
# 5              6    international
# 6              7        beverages
# 7              8             pets
# 8              9  dry goods pasta
# 9             10             bulk

# %% [markdown]
# ### order_products__prior

# %%
order_products__prior = pd.read_csv('order_products__prior.csv')

print(order_products__prior.shape)
order_products__prior.head(10)
# Out:
# (32434489, 4)
#    order_id  product_id  add_to_cart_order  reordered
# 0         2       33120                  1          1
# 1         2       28985                  2          1
# 2         2        9327                  3          0
# 3         2       45918                  4          1
# 4         2       30035                  5          0
# 5         2       17794                  6          1
# 6         2       40141                  7          1
# 7         2        1819                  8          1
# 8         2       43668                  9          0
# 9         3       33754                  1          1

# %%
display(example)
# Out:
# <img src="https://cdn-images-1.medium.com/max/1600/1*vYGFQCafJtGBBX5mbl0xyw.png" width="600"/>

# %% [markdown]
# ### order_products__train

# %%
order_products__train = pd.read_csv('order_products__train.csv')

print(order_products__train.shape)
order_products__train.head(10)
# Out:
# (1384617, 4)
#    order_id  product_id  add_to_cart_order  reordered
# 0         1       49302                  1          1
# 1         1       11109                  2          1
# 2         1       10246                  3          0
# 3         1       49683                  4          0
# 4         1       43633                  5          1
# 5         1       13176                  6          0
# 6         1       47209                  7          0
# 7         1       22035                  8          1
# 8        36       39612                  1          0
# 9        36       19660                  2          1

# %% [markdown]
# ### orders

# %%
orders = pd.read_csv('orders.csv')

print(orders.shape)
orders.head(10)
# Out:
# (3421083, 7)
#    order_id  user_id  ... order_hour_of_day  days_since_prior_order
# 0   2539329        1  ...                 8                     NaN
# 1   2398795        1  ...                 7                    15.0
# 2    473747        1  ...                12                    21.0
# 3   2254736        1  ...                 7                    29.0
# 4    431534        1  ...                15                    28.0
# 5   3367565        1  ...                 7                    19.0
# 6    550135        1  ...                 9                    20.0
# 7   3108588        1  ...                14                    14.0
# 8   2295261        1  ...                16                     0.0
# 9   2550362        1  ...                 8                    30.0
#
# [10 rows x 7 columns]

# %% [markdown]
# from this data set
# we need
#
# user id
# ordr id
# order no

# %% [markdown]
# ### products

# %%
products = pd.read_csv('products.csv')

print(products.shape)
products.head(10)
# Out:
# (49688, 4)
#    product_id  ... department_id
# 0           1  ...            19
# 1           2  ...            13
# 2           3  ...             7
# 3           4  ...             1
# 4           5  ...            13
# 5           6  ...            11
# 6           7  ...             7
# 7           8  ...             1
# 8           9  ...            16
# 9          10  ...             7
#
# [10 rows x 4 columns]

# %% [markdown]
# ## Concatenate order_products__prior and order_products__train

# %%
order_products__prior.shape
# Out:
# (32434489, 4)

# %%
order_products__train.shape
# Out:
# (1384617, 4)

# %% [markdown]
# we can concatenate by cols or by rows.
#
# by default it concatenates rows.
#
# to concatenate by col we have say axis =1
#
# in pandas axis =1 always col
#
# axis = 0 always row

# %%
order_products = pd.concat([order_products__prior,order_products__train])
print(order_products.shape)
# Out:
# (33819106, 4)

# %% [markdown]
# new keyword 'assert' in pandas. works for conditions

# %%
assert 1 == 0
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-17-e99f91a18d62> in <module>()
# ----> 1 assert 1 == 0
#
# AssertionError:

# %%
assert 1 == 1

# %%
# assert if the condition is satisfied or not b4 

assert order_products__prior.shape[0] + order_products__train.shape[0] == order_products.shape[0]

# %%
display(example)
# Out:
# <img src="https://cdn-images-1.medium.com/max/1600/1*vYGFQCafJtGBBX5mbl0xyw.png" width="600"/>

# %% [markdown]
# ## Get a subset of orders — the first two orders for user id 1

# %% [markdown]
# From `orders` dataframe:
# - user_id
# - order_id
# - order_number
# - order_dow
# - order_hour_of_day

# %%
orders.head()
# Out:
#    order_id  user_id  ... order_hour_of_day  days_since_prior_order
# 0   2539329        1  ...                 8                     NaN
# 1   2398795        1  ...                 7                    15.0
# 2    473747        1  ...                12                    21.0
# 3   2254736        1  ...                 7                    29.0
# 4    431534        1  ...                15                    28.0
#
# [5 rows x 7 columns]

# %%
products.head()
# Out:
#    product_id  ... department_id
# 0           1  ...            19
# 1           2  ...            13
# 2           3  ...             7
# 3           4  ...             1
# 4           5  ...            13
#
# [5 rows x 4 columns]

# %%
order_products.head()
# Out:
#    order_id  product_id  add_to_cart_order  reordered
# 0         2       33120                  1          1
# 1         2       28985                  2          1
# 2         2        9327                  3          0
# 3         2       45918                  4          1
# 4         2       30035                  5          0

# %% [markdown]
# ## Merge dataframes

# %% [markdown]
# before merging it is good to subset and have only
#
# those data that is needed for merging. in real
#
# world the sixe of data is so huge that its good
#
# idea to work with the required data.

# %% [markdown]
# Merge the subset from `orders` with columns from `order_products`

# %% [markdown]
# ## Slim down the orders dataframe to only the rows that we need to make our example

# %%
# biitwise & n coditional &&

condition = (orders['user_id'] == 1 ) & (orders['order_number'] <= 2)
col_orders = [
           'user_id',
           'order_id',
           'order_number',
           'order_dow',
           'order_hour_of_day'
]

# %% [markdown]
# ### use .loc to both filter the dataframes and retain specific columns

# %%
orders_subset = orders.loc[condition, col_orders]
orders_subset.head()
# Out:
#    user_id  order_id  order_number  order_dow  order_hour_of_day
# 0        1   2539329             1          2                  8
# 1        1   2398795             2          3                  7

# %%
columns_order_products = ['order_id', 'add_to_cart_order', 'product_id']
print(order_products.shape)
order_products = order_products[columns_order_products]
order_products.head()
# Out:
# (33819106, 4)
#    order_id  add_to_cart_order  product_id
# 0         2                  1       33120
# 1         2                  2       28985
# 2         2                  3        9327
# 3         2                  4       45918
# 4         2                  5       30035

# %% [markdown]
# Merge with columns from `products`

# %% [markdown]
# ### parameter on tells using which col its merged
#
# ### parameter how tells the way the table is joined

# %% [markdown]
# inner join is the default one

# %%
order_products_merged = pd.merge(orders_subset, order_products, how ='inner', on='order_id')

order_products_merged
# Out:
#     user_id  order_id  ...  add_to_cart_order  product_id
# 0         1   2539329  ...                  1         196
# 1         1   2539329  ...                  2       14084
# 2         1   2539329  ...                  3       12427
# 3         1   2539329  ...                  4       26088
# 4         1   2539329  ...                  5       26405
# 5         1   2398795  ...                  1         196
# 6         1   2398795  ...                  2       10258
# 7         1   2398795  ...                  3       12427
# 8         1   2398795  ...                  4       13176
# 9         1   2398795  ...                  5       26088
# 10        1   2398795  ...                  6       13032
#
# [11 rows x 7 columns]

# %%
order_products_complete_forusr1 = pd.merge(order_products_merged,products[['product_id','product_name']],
                                  how='inner',on = 'product_id')
order_products_complete_forusr1
# Out:
#     user_id  order_id  ...  product_id                             product_name
# 0         1   2539329  ...         196                                     Soda
# 1         1   2398795  ...         196                                     Soda
# 2         1   2539329  ...       14084  Organic Unsweetened Vanilla Almond Milk
# 3         1   2539329  ...       12427                      Original Beef Jerky
# 4         1   2398795  ...       12427                      Original Beef Jerky
# 5         1   2539329  ...       26088               Aged White Cheddar Popcorn
# 6         1   2398795  ...       26088               Aged White Cheddar Popcorn
# 7         1   2539329  ...       26405         XL Pick-A-Size Paper Towel Rolls
# 8         1   2398795  ...       10258                               Pistachios
# 9         1   2398795  ...       13176                   Bag of Organic Bananas
# 10        1   2398795  ...       13032                    Cinnamon Toast Crunch
#
# [11 rows x 8 columns]

# %%
# the data is sorted. to do that

order_products_complete_forusr1 = order_products_complete_forusr1.sort_values(by=['order_number','add_to_cart_order'])
order_products_complete_forusr1
# Out:
#     user_id  order_id  ...  product_id                             product_name
# 0         1   2539329  ...         196                                     Soda
# 2         1   2539329  ...       14084  Organic Unsweetened Vanilla Almond Milk
# 3         1   2539329  ...       12427                      Original Beef Jerky
# 5         1   2539329  ...       26088               Aged White Cheddar Popcorn
# 7         1   2539329  ...       26405         XL Pick-A-Size Paper Towel Rolls
# 1         1   2398795  ...         196                                     Soda
# 8         1   2398795  ...       10258                               Pistachios
# 4         1   2398795  ...       12427                      Original Beef Jerky
# 9         1   2398795  ...       13176                   Bag of Organic Bananas
# 6         1   2398795  ...       26088               Aged White Cheddar Popcorn
# 10        1   2398795  ...       13032                    Cinnamon Toast Crunch
#
# [11 rows x 8 columns]

# %%
# change the col header

order_products_complete_forusr1.columns = [column.replace('_', ' ') for column in order_products_complete_forusr1]
order_products_complete_forusr1
# Out:
#     user id  order id  ...  product id                             product name
# 0         1   2539329  ...         196                                     Soda
# 2         1   2539329  ...       14084  Organic Unsweetened Vanilla Almond Milk
# 3         1   2539329  ...       12427                      Original Beef Jerky
# 5         1   2539329  ...       26088               Aged White Cheddar Popcorn
# 7         1   2539329  ...       26405         XL Pick-A-Size Paper Towel Rolls
# 1         1   2398795  ...         196                                     Soda
# 8         1   2398795  ...       10258                               Pistachios
# 4         1   2398795  ...       12427                      Original Beef Jerky
# 9         1   2398795  ...       13176                   Bag of Organic Bananas
# 6         1   2398795  ...       26088               Aged White Cheddar Popcorn
# 10        1   2398795  ...       13032                    Cinnamon Toast Crunch
#
# [11 rows x 8 columns]

# %%
display(example)
# Out:
# <img src="https://cdn-images-1.medium.com/max/1600/1*vYGFQCafJtGBBX5mbl0xyw.png" width="600"/>

# %% [markdown]
# # Reshape Datasets

# %% [markdown]
# ## Why reshape data?
#
# #### Some libraries prefer data in different formats
#
# For example, the Seaborn data visualization library prefers data in "Tidy" format often (but not always).
#
# > "[Seaborn will be most powerful when your datasets have a particular organization.](https://seaborn.pydata.org/introduction.html#organizing-datasets) This format ia alternately called “long-form” or “tidy” data and is described in detail by Hadley Wickham. The rules can be simply stated:
#
# > - Each variable is a column
# - Each observation is a row
#
# > A helpful mindset for determining whether your data are tidy is to think backwards from the plot you want to draw. From this perspective, a “variable” is something that will be assigned a role in the plot."
#
# #### Data science is often about putting square pegs in round holes
#
# Here's an inspiring [video clip from _Apollo 13_](https://www.youtube.com/watch?v=ry55--J4_VQ): “Invent a way to put a square peg in a round hole.” It's a good metaphor for data wrangling!

# %% [markdown]
# ## Hadley Wickham's Examples
#
# From his paper, [Tidy Data](http://vita.had.co.nz/papers/tidy-data.html)

# %%
# %matplotlib inline
import pandas as pd
import numpy as np
import seaborn as sns

table1 = pd.DataFrame(
    [[np.nan, 2],
     [16,    11], 
     [3,      1]],
    index=['John Smith', 'Jane Doe', 'Mary Johnson'], 
    columns=['treatmenta', 'treatmentb'])

table2 = table1.T

# %% [markdown]
# "Table 1 provides some data about an imaginary experiment in a format commonly seen in the wild.
#
# The table has two columns and three rows, and both rows and columns are labelled."

# %%
table1
# Out:
#               treatmenta  treatmentb
# John Smith           NaN           2
# Jane Doe            16.0          11
# Mary Johnson         3.0           1

# %% [markdown]
# "There are many ways to structure the same underlying data.
#
# Table 2 shows the same data as Table 1, but the rows and columns have been transposed. The data is the same, but the layout is different."

# %%
table2
# Out:
#             John Smith  Jane Doe  Mary Johnson
# treatmenta         NaN      16.0           3.0
# treatmentb         2.0      11.0           1.0

# %% [markdown]
# "Table 3 reorganises Table 1 to make the values, variables and obserations more clear.
#
# Table 3 is the tidy version of Table 1. Each row represents an observation, the result of one treatment on one person, and each column is a variable."
#
# | name         | trt | result |
# |--------------|-----|--------|
# | John Smith   | a   | -      |
# | Jane Doe     | a   | 16     |
# | Mary Johnson | a   | 3      |
# | John Smith   | b   | 2      |
# | Jane Doe     | b   | 11     |
# | Mary Johnson | b   | 1      |

# %% [markdown]
# ## Table 1 --> Tidy
#
# We can use the pandas `melt` function to reshape Table 1 into Tidy format.
#
# converts from wide format to long format

# %%
#table1.reset_index()
table1 = table1.reset_index()

# %%
table1
# Out:
#           index  treatmenta  treatmentb
# 0    John Smith         NaN           2
# 1      Jane Doe        16.0          11
# 2  Mary Johnson         3.0           1

# %%
tidy1 = table1.melt(id_vars='index')
tidy1
#pd.melt
# Out:
#           index    variable  value
# 0    John Smith  treatmenta    NaN
# 1      Jane Doe  treatmenta   16.0
# 2  Mary Johnson  treatmenta    3.0
# 3    John Smith  treatmentb    2.0
# 4      Jane Doe  treatmentb   11.0
# 5  Mary Johnson  treatmentb    1.0

# %%
tidy1 = table1.melt(id_vars='index', value_vars=['treatmenta','treatmentb'])
tidy1
# Out:
#           index    variable  value
# 0    John Smith  treatmenta    NaN
# 1      Jane Doe  treatmenta   16.0
# 2  Mary Johnson  treatmenta    3.0
# 3    John Smith  treatmentb    2.0
# 4      Jane Doe  treatmentb   11.0
# 5  Mary Johnson  treatmentb    1.0

# %%
# to rename the cols --> old name : new name

tidy1 = tidy1.rename(columns={
    'index': 'name', 
    'variable': 'trt', 
    'value': 'result'
})

tidy1
# Out:
#            name         trt  result
# 0    John Smith  treatmenta     NaN
# 1      Jane Doe  treatmenta    16.0
# 2  Mary Johnson  treatmenta     3.0
# 3    John Smith  treatmentb     2.0
# 4      Jane Doe  treatmentb    11.0
# 5  Mary Johnson  treatmentb     1.0

# %%
# tidy1.trt = tidy1.trt.str.replace('treatment', '')
# other way of doing,[] is preferred convention

tidy1['trt'] = tidy1['trt'].str.replace('treatment','')
#tidy1

# %%
tidy1
# Out:
#            name trt  result
# 0    John Smith   a     NaN
# 1      Jane Doe   a    16.0
# 2  Mary Johnson   a     3.0
# 3    John Smith   b     2.0
# 4      Jane Doe   b    11.0
# 5  Mary Johnson   b     1.0

# %% [markdown]
# ## Table 2 --> Tidy

# %%
##### LEAVE BLANK --an assignment exercise #####

# %%
table2
# Out:
#             John Smith  Jane Doe  Mary Johnson
# treatmenta         NaN      16.0           3.0
# treatmentb         2.0      11.0           1.0

# %%
# first reset index for table2 to make the treatments as part of the table

table2 = table2.reset_index()

# %%
table2
# Out:
#         index  John Smith  Jane Doe  Mary Johnson
# 0  treatmenta         NaN      16.0           3.0
# 1  treatmentb         2.0      11.0           1.0

# %%
# use .melt command to make the table to tidy format

tidy2 = table2.melt(id_vars='index')
tidy2
# Out:
#         index      variable  value
# 0  treatmenta    John Smith    NaN
# 1  treatmentb    John Smith    2.0
# 2  treatmenta      Jane Doe   16.0
# 3  treatmentb      Jane Doe   11.0
# 4  treatmenta  Mary Johnson    3.0
# 5  treatmentb  Mary Johnson    1.0

# %%
tidy2 = table2.melt(id_vars='index',value_vars=['John Smith','Jane Doe','Mary Johnson'])
tidy2
# Out:
#         index      variable  value
# 0  treatmenta    John Smith    NaN
# 1  treatmentb    John Smith    2.0
# 2  treatmenta      Jane Doe   16.0
# 3  treatmentb      Jane Doe   11.0
# 4  treatmenta  Mary Johnson    3.0
# 5  treatmentb  Mary Johnson    1.0

# %%
# to change the col names

tidy2 = tidy2.rename(columns={
    'index': 'trt', 
    'variable': 'name', 
    'value': 'result'
})

tidy2
# Out:
#           trt          name  result
# 0  treatmenta    John Smith     NaN
# 1  treatmentb    John Smith     2.0
# 2  treatmenta      Jane Doe    16.0
# 3  treatmentb      Jane Doe    11.0
# 4  treatmenta  Mary Johnson     3.0
# 5  treatmentb  Mary Johnson     1.0

# %%
tidy2['trt'] = tidy2['trt'].str.replace('treatment','')
tidy2
# Out:
#   trt          name  result
# 0   a    John Smith     NaN
# 1   b    John Smith     2.0
# 2   a      Jane Doe    16.0
# 3   b      Jane Doe    11.0
# 4   a  Mary Johnson     3.0
# 5   b  Mary Johnson     1.0

# %% [markdown]
# ## Tidy --> Table 1
#
# The `pivot_table` function is the inverse of `melt`.
#
# converts from long format to wide format

# %%
wide1 = tidy1.pivot_table(index='name', columns='trt', values='result')

# %%
wide1
# Out:
# trt              a     b
# name
# Jane Doe      16.0  11.0
# John Smith     NaN   2.0
# Mary Johnson   3.0   1.0

# %% [markdown]
# ## Tidy --> Table 2

# %%
##### LEAVE BLANK --an assignment exercise #####

wide2 = tidy2.pivot_table(index='trt', columns='name', values='result')
wide2
# Out:
# name  Jane Doe  John Smith  Mary Johnson
# trt
# a         16.0         NaN           3.0
# b         11.0         2.0           1.0

# %% [markdown]
# # Seaborn example
#
# The rules can be simply stated:
#
# - Each variable is a column
# - Each observation is a row
#
# A helpful mindset for determining whether your data are tidy is to think backwards from the plot you want to draw. From this perspective, a “variable” is something that will be assigned a role in the plot."

# %%
sns.catplot(x='trt', y='result', col='name', 
            kind='bar', data=tidy1, height=2);

# %% [markdown]
# ## Now with Instacart data

# %%
products = pd.read_csv('products.csv')

order_products = pd.concat([pd.read_csv('order_products__prior.csv'), 
                            pd.read_csv('order_products__train.csv')])

orders = pd.read_csv('orders.csv')

# %% [markdown]
# ## Goal: Reproduce part of this example
#
# Instead of a plot with 50 products, we'll just do two — the first products from each list
# - Half And Half Ultra Pasteurized
# - Half Baked Frozen Yogurt

# %%
from IPython.display import display, Image
url = 'https://cdn-images-1.medium.com/max/1600/1*wKfV6OV-_1Ipwrl7AjjSuw.png'
example = Image(url=url, width=600)

display(example)
# Out:
# <img src="https://cdn-images-1.medium.com/max/1600/1*wKfV6OV-_1Ipwrl7AjjSuw.png" width="600"/>

# %% [markdown]
# So, given a `product_name` we need to calculate its `order_hour_of_day` pattern.

# %% [markdown]
# ## Subset and Merge
#
# One challenge of performing a merge on this data is that the `products` and `orders` datasets do not have any common columns that we can merge on. Due to this we will have to use the `order_products` dataset to provide the columns that we will use to perform the merge.

# %%
product= ['Half Baked Frozen Yogurt', "Half And Half Ultra Pasteurized"]

# %%
orders.columns.tolist()
# Out:
# ['order_id',
#  'user_id',
#  'eval_set',
#  'order_number',
#  'order_dow',
#  'order_hour_of_day',
#  'days_since_prior_order']

# %%
order_products.columns.tolist()
# Out:
# ['order_id', 'product_id', 'add_to_cart_order', 'reordered']

# %% [markdown]
# looking for the data we are interested in

# %%
products_condition = ((products['product_name'] == 'Half Baked Frozen Yogurt') |
                            (products['product_name'] == 'Half And Half Ultra Pasteurized'))

# %%
products_we_need = products[products_condition]

# %%
merged = (products_we_need[['product_id', 'product_name']]
          .merge(order_products[['order_id', 'product_id']])
          .merge(orders[['order_id', 'order_hour_of_day']]))

# %%
merged
# Out:
#       product_id                     product_name  order_id  order_hour_of_day
# 0           9292  Half And Half Ultra Pasteurized        64                 16
# 1           9292  Half And Half Ultra Pasteurized      1883                 11
# 2           9292  Half And Half Ultra Pasteurized      5625                  9
# 3           9292  Half And Half Ultra Pasteurized      7765                 14
# 4           9292  Half And Half Ultra Pasteurized      7906                  9
# 5           9292  Half And Half Ultra Pasteurized      8495                 16
# 6           9292  Half And Half Ultra Pasteurized      8684                  7
# 7           9292  Half And Half Ultra Pasteurized      9456                 11
# 8           9292  Half And Half Ultra Pasteurized      9498                 14
# 9           9292  Half And Half Ultra Pasteurized     11077                 16
# 10          9292  Half And Half Ultra Pasteurized     12626                 20
# 11          9292  Half And Half Ultra Pasteurized     15421                 11
# 12          9292  Half And Half Ultra Pasteurized     16115                 16
# 13          9292  Half And Half Ultra Pasteurized     17736                 10
# 14          9292  Half And Half Ultra Pasteurized     17766                  8
# 15          9292  Half And Half Ultra Pasteurized     17809                 12
# 16          9292  Half And Half Ultra Pasteurized     18212                 11
# 17          9292  Half And Half Ultra Pasteurized     19961                 10
# 18          9292  Half And Half Ultra Pasteurized     21390                  8
# 19          9292  Half And Half Ultra Pasteurized     22042                 15
# 20          9292  Half And Half Ultra Pasteurized     22466                  9
# 21          9292  Half And Half Ultra Pasteurized     22471                 11
# 22          9292  Half And Half Ultra Pasteurized     25331                 16
# 23          9292  Half And Half Ultra Pasteurized     30300                  8
# 24          9292  Half And Half Ultra Pasteurized     30318                 10
# 25          9292  Half And Half Ultra Pasteurized     30957                 12
# 26          9292  Half And Half Ultra Pasteurized     31619                 10
# 27          9292  Half And Half Ultra Pasteurized     32209                  9
# 28          9292  Half And Half Ultra Pasteurized     34135                 11
# 29          9292  Half And Half Ultra Pasteurized     34833                  9
# ...          ...                              ...       ...                ...
# 5948       30668         Half Baked Frozen Yogurt   2720280                 10
# 5949       30668         Half Baked Frozen Yogurt   2727518                 16
# 5950       30668         Half Baked Frozen Yogurt   2730589                 19
# 5951       30668         Half Baked Frozen Yogurt   2799790                 16
# 5952       30668         Half Baked Frozen Yogurt   2806203                 12
# 5953       30668         Half Baked Frozen Yogurt   2807292                 18
# 5954       30668         Half Baked Frozen Yogurt   2809756                 19
# 5955       30668         Half Baked Frozen Yogurt   2818341                 12
# 5956       30668         Half Baked Frozen Yogurt   2822161                 10
# 5957       30668         Half Baked Frozen Yogurt   2899577                 18
# 5958       30668         Half Baked Frozen Yogurt   2904974                 18
# 5959       30668         Half Baked Frozen Yogurt   2939092                 12
# 5960       30668         Half Baked Frozen Yogurt   2966781                 22
# 5961       30668         Half Baked Frozen Yogurt   3027892                 18
# 5962       30668         Half Baked Frozen Yogurt   3036463                 19
# 5963       30668         Half Baked Frozen Yogurt   3045306                 16
# 5964       30668         Half Baked Frozen Yogurt   3093462                 17
# 5965       30668         Half Baked Frozen Yogurt   3130110                 20
# 5966       30668         Half Baked Frozen Yogurt   3143184                 16
# 5967       30668         Half Baked Frozen Yogurt   3175853                 19
# 5968       30668         Half Baked Frozen Yogurt   3177784                 15
# 5969       30668         Half Baked Frozen Yogurt   3192765                 10
# 5970       30668         Half Baked Frozen Yogurt   3218068                 16
# 5971       30668         Half Baked Frozen Yogurt   3234277                 20
# 5972       30668         Half Baked Frozen Yogurt   3303828                 14
# 5973       30668         Half Baked Frozen Yogurt   3322557                 15
# 5974       30668         Half Baked Frozen Yogurt   3326481                 18
# 5975       30668         Half Baked Frozen Yogurt   3353089                 13
# 5976       30668         Half Baked Frozen Yogurt   3378210                 16
# 5977       30668         Half Baked Frozen Yogurt   3396341                  8
#
# [5978 rows x 4 columns]

# %%
### another way for choosing the data we need

product_names = ['Half Baked Frozen Yogurt', 'Half And Half Ultra Pasteurized']

condition = products['product_name'].isin(product_names)

subset = products[condition]
print(subset.shape)
subset.head()
# Out:
# (2, 4)
#        product_id                     product_name  aisle_id  department_id
# 9291         9292  Half And Half Ultra Pasteurized        84             16
# 30667       30668         Half Baked Frozen Yogurt        37              1

# %% [markdown]
# ## 4 ways to reshape and plot

# %%
#froyo = subset[subset['product_name']=='Half Baked Frozen Yogurt']
#cream = subset[subset['product_name']=='Half And Half Ultra Pasteurized']

froyo =merged[merged['product_name']=='Half Baked Frozen Yogurt']

cream = merged[merged['product_name']=='Half And Half Ultra Pasteurized']

# %% [markdown]
# ### 1. value_counts

# %%
froyo.head()
# Out:
#       product_id              product_name  order_id  order_hour_of_day
# 2836       30668  Half Baked Frozen Yogurt   3321431                 13
# 2907       30668  Half Baked Frozen Yogurt   3404398                 14
# 2997       30668  Half Baked Frozen Yogurt       917                 12
# 2998       30668  Half Baked Frozen Yogurt      1653                 13
# 2999       30668  Half Baked Frozen Yogurt      4565                  2

# %%
cream.head()
# Out:
#    product_id                     product_name  order_id  order_hour_of_day
# 0        9292  Half And Half Ultra Pasteurized        64                 16
# 1        9292  Half And Half Ultra Pasteurized      1883                 11
# 2        9292  Half And Half Ultra Pasteurized      5625                  9
# 3        9292  Half And Half Ultra Pasteurized      7765                 14
# 4        9292  Half And Half Ultra Pasteurized      7906                  9

# %%
cream['order_hour_of_day'].value_counts().sort_index()
# Out:
# 0       6
# 1       1
# 2       1
# 4       1
# 5       4
# 6      25
# 7      95
# 8     323
# 9     480
# 10    429
# 11    292
# 12    200
# 13    213
# 14    215
# 15    222
# 16    218
# 17    111
# 18     56
# 19     28
# 20     32
# 21     23
# 22     12
# 23      8
# Name: order_hour_of_day, dtype: int64

# %%
cream['order_hour_of_day'].value_counts(normalize=True).sort_index()
# Out:
# 0     0.002003
# 1     0.000334
# 2     0.000334
# 4     0.000334
# 5     0.001336
# 6     0.008347
# 7     0.031720
# 8     0.107846
# 9     0.160267
# 10    0.143239
# 11    0.097496
# 12    0.066778
# 13    0.071119
# 14    0.071786
# 15    0.074124
# 16    0.072788
# 17    0.037062
# 18    0.018698
# 19    0.009349
# 20    0.010684
# 21    0.007679
# 22    0.004007
# 23    0.002671
# Name: order_hour_of_day, dtype: float64

# %%
cream['order_hour_of_day'].value_counts(normalize=True).sort_index().reset_index()
# Out:
#     index  order_hour_of_day
# 0       0           0.002003
# 1       1           0.000334
# 2       2           0.000334
# 3       4           0.000334
# 4       5           0.001336
# 5       6           0.008347
# 6       7           0.031720
# 7       8           0.107846
# 8       9           0.160267
# 9      10           0.143239
# 10     11           0.097496
# 11     12           0.066778
# 12     13           0.071119
# 13     14           0.071786
# 14     15           0.074124
# 15     16           0.072788
# 16     17           0.037062
# 17     18           0.018698
# 18     19           0.009349
# 19     20           0.010684
# 20     21           0.007679
# 21     22           0.004007
# 22     23           0.002671

# %%
(cream['order_hour_of_day']
 .value_counts(normalize=True)
 .sort_index()
 .plot())

(froyo['order_hour_of_day']
 .value_counts(normalize=True)
 .sort_index()
 .plot());

# %% [markdown]
# ### normalise to show as percentage

# %% [markdown]
#  ### 2. crosstab

# %% [markdown]
# ### 3. Pivot Table

# %% [markdown]
# ### 4. melt
